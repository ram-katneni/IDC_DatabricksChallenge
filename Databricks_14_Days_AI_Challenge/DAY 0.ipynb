# %% [markdown]
# # 1. Install Dependencies

# %%
# %pip install kaggle

# %% [markdown]
# # 2. Configure Kaggle Credentials

# %%
import os

os.environ["KAGGLE_USERNAME"] = "ramakatneni"
os.environ["KAGGLE_KEY"] = "KGAT_923604c568683826eb588659b8cdeeb5"

print("Kaggle credentials configured!")

# %% [markdown]
# #3. Create Database Schema

# %%
spark.sql("""
CREATE SCHEMA IF NOT EXISTS workspace.ecommerce
""")

# %% [markdown]
# # 4. Create Volume for Data Storage

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data
""")

# %% [markdown]
# # 5. Download Dataset from Kaggle

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store

# %% [markdown]
# #6. Extract Downloaded Dataset

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
unzip -o ecommerce-behavior-data-from-multi-category-store.zip
ls -lh

# %% [markdown]
# #7. Clean Up Zip File

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
rm -f ecommerce-behavior-data-from-multi-category-store.zip
ls -lh

# %% [markdown]
# #8. Restart Python Environment

# %%
# %restart_python

# %% [markdown]
# #9. Load Oct 2019 Data

# %%
oct_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

# %% [markdown]
# #10. Load Nov 2019 Data

# %%
nov_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv")

# %% [markdown]
# #11. Display Dataset Statistics and Schema

# %%
print(f"October 2019 - Total Events: {oct_df.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
oct_df.printSchema()

# %%
print(f"November 2019 - Total Events: {nov_df.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
nov_df.printSchema()

# %% [markdown]
# #12. Display Sample Data

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
oct_df.show(5, truncate=False)

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
nov_df.show(5, truncate=False)

# %% [markdown]
# #Sample Results

# %%
display(nov_df.limit(5))
