# %% [markdown]
# #DAY 07 – Workflows & Job Orchestration

# %% [markdown]
# ## Design, parameterize, orchestrate, schedule, and monitor a Bronze → Silver → Gold production pipeline using Databricks Jobs with data quality checks.”

# %% [markdown]
# Databricks Notebooks vs Jobs (Interview-ready)
# Aspect	Notebook	Job
# Purpose	Development & exploration	Production execution
# Execution	Manual / ad-hoc	Scheduled / triggered
# Dependencies	❌ No	✅ Yes (multi-task workflows)
# Parameters	Widgets	Job parameters
# Error handling	Manual	Automatic retries, alerts
# SLA	❌	✅
#
# 👉 Rule of thumb
#
# Notebook = code
#
# Job = orchestration

# %% [markdown]
# Job: ecommerce_medallion_pipeline
# │
# ├── Task 1: bronze_ingestion_nb
# │
# ├── Task 2: silver_processing_nb (depends on Bronze)
# │
# └── Task 3: gold_aggregation_nb (depends on Silver)
